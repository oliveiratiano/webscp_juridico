# %% [markdown]
# # Crawler de decisões ESAJ
# #### Este notebook possui um crawler das decisões do ESAJ de primeira instância.
# ## Imports e funções

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
from selenium import webdriver
re_conteudo = re.compile('(?<=</strong>)(.+)(?=</td>)', flags = re.DOTALL)
re_teor = re.compile('(?<=<span>)(.+)(?=</span>)', flags = re.DOTALL)
re_remhtml = re.compile('<.*?>', flags = re.DOTALL)

def extrair_dados_decisao(decisao): 
    id = classe = assunto = magistrado = comarca = foro = vara = data = None
    id = decisao.find_all('tr')[0].find('span', class_='fonteNegrito').get_text().strip()
    for elemento in decisao.find_all('tr'):
        if elemento.find('strong') != None:
            if elemento.find('strong').get_text().strip() == "Classe:":
                classe = re_conteudo.search(str(elemento))[0].strip()
            elif elemento.find('strong').get_text().strip() == "Assunto:":
                assunto = re_conteudo.search(str(elemento))[0].strip()
            elif elemento.find('strong').get_text().strip() == "Magistrado:":
                magistrado = re_conteudo.search(str(elemento))[0].strip()
            elif elemento.find('strong').get_text().strip() == "Comarca:":
                comarca = re_conteudo.search(str(elemento))[0].strip()
            elif elemento.find('strong').get_text().strip() == "Foro:":
                foro = re_conteudo.search(str(elemento))[0].strip()
            elif elemento.find('strong').get_text().strip() == "Vara:":
                vara = re_conteudo.search(str(elemento))[0].strip()
            elif elemento.find('strong').get_text().strip() == "Data de Disponibilização:":
                data = re_conteudo.search(str(elemento))[0].strip()
        else:
            teor = re_teor.search(str(elemento.find_all('span')[:][1:]))
        
    return((id, classe, assunto, magistrado, comarca, foro, vara, data, re.sub(re_remhtml, '', teor[0])))

def listar_dados_pagina(pagina, driver):
    pagina = str(pagina)
    driver.execute_script("var trocarDePagina = function(pagina){$('div#divDadosResultado').fadeTo('slow', 0.33);$.get(window.saj.env.root+'/trocarDePagina.do', { pagina: pagina}, function(data){atualizarPagina(data)} );};var atualizarPagina = function(data){var div = $('div#resultados');div.html(data);var divResultado = $('div#divDadosResultado', div);divResultado.hide();divResultado.fadeIn('slow');bindPaginacao();var campoPesquisa = $('input[name=dadosConsulta.pesquisaLivre]');bindTermosRelacionados(campoPesquisa);bindImagemMostrarOcultarConteudo();bindLinkDownloadDocumento();};trocarDePagina("+pagina+")")
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    lista_decisoes_pagina = soup.find_all('tr', class_='fundocinza1')
    lista_dados = [extrair_dados_decisao(decisao) for decisao in lista_decisoes_pagina]
    return lista_dados

# %% [markdown]
# ### Fazendo a mágica acontecer

# %%
driver = webdriver.Firefox(executable_path = 'D:\\programas\\geckodriver\\geckodriver.exe')
driver.get('http://esaj.tjsp.jus.br/cjpg/pesquisar.do?conversationId=&dadosConsulta.pesquisaLivre=JULG*&tipoNumero=UNIFICADO&numeroDigitoAnoUnificado=&foroNumeroUnificado=&dadosConsulta.nuProcesso=&dadosConsulta.nuProcessoAntigo=&classeTreeSelection.values=&classeTreeSelection.text=&assuntoTreeSelection.values=&assuntoTreeSelection.text=&agenteSelectedEntitiesList=&contadoragente=0&contadorMaioragente=0&cdAgente=&nmAgente=&dadosConsulta.dtInicio=&dadosConsulta.dtFim=&varasTreeSelection.values=&varasTreeSelection.text=&dadosConsulta.ordenacao=DESC#')
dados_extraidos = []
for i in range(0,500):
    dados_extraidos = dados_extraidos + listar_dados_pagina(i,driver)
df = pd.DataFrame(dados_extraidos, columns =['id', 'Classe', 'Assunto', 'Magistrado', 'Comarca', 'Foro', 'Vara', 'Data_disp', 'Teor'])
df.head()
# Out:
#                           id  \
# 0  1000315-72.2016.8.26.0156
# 1  1041537-33.2019.8.26.0053
# 2  1006867-71.2016.8.26.0053
# 3  0004761-08.2016.8.26.0457
# 4  1002795-22.2018.8.26.0457
#
#                                               Classe                Assunto  \
# 0  Despejo por Falta de Pagamento Cumulado Com Co...      Locação de Imóvel
# 1                           Procedimento Comum Cível             Voluntária
# 2                                     Desapropriação         Desapropriação
# 3                Ação Penal - Procedimento Ordinário     Crimes de Trânsito
# 4                            Cumprimento de sentença  Prestação de Serviços
#
#                   Magistrado       Comarca  \
# 0  FERNANDO OLIVEIRA CAMARGO      Cruzeiro
# 1  Alexandra Fuchs de Araujo     SÃO PAULO
# 2  Alexandra Fuchs de Araujo     SÃO PAULO
# 3    DONEK HILSENRATH GARCIA  Pirassununga
# 4    DONEK HILSENRATH GARCIA  Pirassununga
#
#                                        Foro                        Vara  \
# 0                          Foro de Cruzeiro               2ª Vara Cível
# 1  Foro Central - Fazenda Pública/Acidentes  6ª Vara de Fazenda Pública
# 2  Foro Central - Fazenda Pública/Acidentes  6ª Vara de Fazenda Pública
# 3                      Foro de Pirassununga                     1ª Vara
# 4                      Foro de Pirassununga                     1ª Vara
#
#     Data_disp                                               Teor
# 0  01/10/3199  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 1  26/10/2019  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 2  26/10/2019  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 3  26/10/2019  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 4  26/10/2019  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...

# %%
df.to_csv('pags_1_100_')
# Out:
#                              id  \
# 0     1000315-72.2016.8.26.0156
# 1     1041537-33.2019.8.26.0053
# 2     1006867-71.2016.8.26.0053
# 3     0004761-08.2016.8.26.0457
# 4     1002795-22.2018.8.26.0457
# 5     1003044-36.2019.8.26.0457
# 6     1002870-27.2019.8.26.0457
# 7     1002258-89.2019.8.26.0457
# 8     1002422-54.2019.8.26.0457
# 9     0004544-71.2019.8.26.0032
# 10    0009954-47.2018.8.26.0032
# 11    1000695-63.2018.8.26.0144
# 12    1000238-19.2019.8.26.0169
# 13    1016306-84.2019.8.26.0576
# 14    0002094-75.2019.8.26.0576
# 15    1000315-72.2016.8.26.0156
# 16    1041537-33.2019.8.26.0053
# 17    1006867-71.2016.8.26.0053
# 18    0004761-08.2016.8.26.0457
# 19    1002795-22.2018.8.26.0457
# 20    1003044-36.2019.8.26.0457
# 21    1002870-27.2019.8.26.0457
# 22    1002258-89.2019.8.26.0457
# 23    1002422-54.2019.8.26.0457
# 24    0004544-71.2019.8.26.0032
# 25    0009954-47.2018.8.26.0032
# 26    1000695-63.2018.8.26.0144
# 27    1000238-19.2019.8.26.0169
# 28    1016306-84.2019.8.26.0576
# 29    0002094-75.2019.8.26.0576
# ...                         ...
# 7470  0007928-36.2016.8.26.0068
# 7471  1002687-63.2019.8.26.0099
# 7472  0009463-88.2009.8.26.0506
# 7473  0020013-56.2019.8.26.0001
# 7474  1002842-88.2019.8.26.0318
# 7475  0017100-41.2019.8.26.0506
# 7476  1007582-26.2019.8.26.0048
# 7477  1007943-14.2017.8.26.0048
# 7478  1020289-70.2019.8.26.0001
# 7479  1008625-95.2019.8.26.0048
# 7480  0007211-81.2014.8.26.0201
# 7481  0011147-56.2019.8.26.0002
# 7482  1006427-22.2018.8.26.0048
# 7483  0003988-90.1996.8.26.0318
# 7484  0005856-36.2014.8.26.0201
# 7485  1594450-38.2018.8.26.0224
# 7486  1000111-43.2001.8.26.0127
# 7487  1002289-79.2018.8.26.0543
# 7488  1592904-45.2018.8.26.0224
# 7489  0505213-90.2013.8.26.0642
# 7490  1004162-90.2019.8.26.0281
# 7491  1586509-37.2018.8.26.0224
# 7492  1051646-43.2018.8.26.0053
# 7493  0018252-72.2012.8.26.0053
# 7494  0505342-95.2013.8.26.0642
# 7495  1586205-38.2018.8.26.0224
# 7496  1585625-08.2018.8.26.0224
# 7497  1580853-02.2018.8.26.0224
# 7498  1566963-93.2018.8.26.0224
# 7499  1003121-52.2019.8.26.0099
#
#                                                  Classe  \
# 0     Despejo por Falta de Pagamento Cumulado Com Co...
# 1                              Procedimento Comum Cível
# 2                                        Desapropriação
# 3                   Ação Penal - Procedimento Ordinário
# 4                               Cumprimento de sentença
# 5                              Procedimento Comum Cível
# 6                                             Monitória
# 7                                             Monitória
# 8             Busca e Apreensão em Alienação Fiduciária
# 9      Cumprimento de Sentença contra a Fazenda Pública
# 10                                              Indulto
# 11               Procedimento do Juizado Especial Cível
# 12                             Procedimento Comum Cível
# 13                             Procedimento Comum Cível
# 14                              Cumprimento de sentença
# 15    Despejo por Falta de Pagamento Cumulado Com Co...
# 16                             Procedimento Comum Cível
# 17                                       Desapropriação
# 18                  Ação Penal - Procedimento Ordinário
# 19                              Cumprimento de sentença
# 20                             Procedimento Comum Cível
# 21                                            Monitória
# 22                                            Monitória
# 23            Busca e Apreensão em Alienação Fiduciária
# 24     Cumprimento de Sentença contra a Fazenda Pública
# 25                                              Indulto
# 26               Procedimento do Juizado Especial Cível
# 27                             Procedimento Comum Cível
# 28                             Procedimento Comum Cível
# 29                              Cumprimento de sentença
# ...                                                 ...
# 7470                Ação Penal - Procedimento Ordinário
# 7471                                          Usucapião
# 7472                                               None
# 7473             Procedimento do Juizado Especial Cível
# 7474                           Procedimento Comum Cível
# 7475                            Cumprimento de sentença
# 7476                           Procedimento Comum Cível
# 7477                           Procedimento Comum Cível
# 7478                           Procedimento Comum Cível
# 7479                      Alvará Judicial - Lei 6858/80
# 7480                                    Execução Fiscal
# 7481             Procedimento do Juizado Especial Cível
# 7482                                          Usucapião
# 7483                   Execução de Título Extrajudicial
# 7484                   Execução de Título Extrajudicial
# 7485                                    Execução Fiscal
# 7486                Ação Penal - Procedimento Ordinário
# 7487                           Procedimento Comum Cível
# 7488                                    Execução Fiscal
# 7489                                    Execução Fiscal
# 15                                        2ª Vara Cível  01/10/3199
# 16                           6ª Vara de Fazenda Pública  26/10/2019
# 17                           6ª Vara de Fazenda Pública  26/10/2019
# 18                                              1ª Vara  26/10/2019
# 19                                              1ª Vara  26/10/2019
# 20                                              1ª Vara  26/10/2019
# 21                                              1ª Vara  26/10/2019
# 22                                              1ª Vara  26/10/2019
# 23                                              1ª Vara  26/10/2019
# 24    2ª Vara das Execuções Criminais e Anexo da Inf...  26/10/2019
# 25    2ª Vara das Execuções Criminais e Anexo da Inf...  26/10/2019
# 26                         Anexo Juizado Especial Cível  26/10/2019
# 27                                           Vara Única  26/10/2019
# 28                                        4ª Vara Cível  26/10/2019
# 29                                        4ª Vara Cível  26/10/2019
# ...                                                 ...         ...
# 7470                                   1ª Vara Criminal  24/10/2019
# 7471                                      4ª Vara Cível  24/10/2019
# 7472                                      9ª Vara Cível  24/10/2019
# 7473                                               None  24/10/2019
# 7474                                      1ª Vara Cível  24/10/2019
# 7475                                     10ª Vara Cível  24/10/2019
# 7476                                      3ª Vara Cível  24/10/2019
# 7477                                      3ª Vara Cível  24/10/2019
# 7478                                      2ª Vara Cível  24/10/2019
# 7479                                      3ª Vara Cível  24/10/2019
# 7480                                            3ª Vara  24/10/2019
# 7481                 Juizado Especial Cível Anexo UNISA  24/10/2019
# 7482                                      3ª Vara Cível  24/10/2019
# 7483                                      1ª Vara Cível  24/10/2019
# 7484                                            3ª Vara  24/10/2019
# 7485                         2ª Vara da Fazenda Pública  24/10/2019
# 7486                                   1ª Vara Criminal  24/10/2019
# 7487                                            2ª Vara  24/10/2019
# 7488                         2ª Vara da Fazenda Pública  24/10/2019
# 7489                         Serviço Anexo das Fazendas  24/10/2019
# 7490                                      1ª Vara Cível  24/10/2019
# 7491                         2ª Vara da Fazenda Pública  24/10/2019
# 7492                   5ª Vara de Acidentes do Trabalho  24/10/2019
# 7493                   4ª Vara de Acidentes do Trabalho  24/10/2019
# 7494                         Serviço Anexo das Fazendas  24/10/2019
# 7495                         2ª Vara da Fazenda Pública  24/10/2019
# 7496                         2ª Vara da Fazenda Pública  24/10/2019
# 7497                         2ª Vara da Fazenda Pública  24/10/2019
# 7498                         2ª Vara da Fazenda Pública  24/10/2019
# 7499                                      2ª Vara Cível  24/10/2019
#
#                                                    Teor
# 0     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 1     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 2     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 3     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 4     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 5     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 6     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 8     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 9     \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 10    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 11    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 12    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 13    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 14    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 15    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 16    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 17    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 18    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 19    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 20    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 21    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 22    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 23    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 24    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 25    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 26    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 27    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 28    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 29    \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# ...                                                 ...
# 7470  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7471  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7472  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7473  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7474  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7475  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7476  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nPODER JUDICI...
# 7477  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nPODER JUDICI...
# 7478  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nSÃO PAULO\n\...
# 7479  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nPODER JUDICI...
# 7480  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7481  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7482  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nPODER JUDICI...
# 7483  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7484  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7485  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7486  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7487  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7488  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7489  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7490  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7491  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7492  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7493  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7494  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7495  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7496  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7497  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7498  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
# 7499  \n\t\t\t\t\t\t\t\t\t\t\t\t\t\n\n\nTRIBUNAL DE ...
#
# [7500 rows x 9 columns]

# %%
500*15
# Out:
# 7500
